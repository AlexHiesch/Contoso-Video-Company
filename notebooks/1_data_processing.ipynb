# %%
import requests
import json
import pandas as pd
import time
import os
import ast # Needed for safely evaluating string representations of lists/dicts
from azure.core.credentials import AzureKeyCredential
from azure.search.documents import SearchClient
from azure.search.documents.indexes import SearchIndexClient
from azure.search.documents.indexes.models import (
    SearchIndex,
    SearchField,
    SearchFieldDataType,
    SimpleField,
    SearchableField,
    VectorSearch,
    VectorSearchProfile,
    HnswAlgorithmConfiguration,
    # Optional: Semantic Search Imports
    # SemanticSearch,
    # SemanticConfiguration,
    # SemanticPrioritizedFields,
    # SemanticField,
)
from math import ceil # For batching
from dotenv import load_dotenv

# --- Load Environment Variables ---
# Ensure you have a .env file in the parent directory (../.env)
# or adjust the path in load_dotenv()
load_dotenv("../.env")

# --- Configuration ---

# Data Source Config
FILE_PATH = os.getenv("SOURCE_FILE_PATH", "movies_metadata.csv") # Default filename if not set
if not FILE_PATH:
    print("Error: SOURCE_FILE_PATH environment variable not set.")
    exit()
# Define how many records to process from the start of the file
RECORDS_TO_PROCESS = None # <<< Adjust as needed. Start small for testing. >>>
# Define columns to read from CSV and use for combined text + ID
# Make sure 'id' column exists and is suitable as a unique key for Azure Search
COLUMNS_TO_READ = ['id', 'title', 'overview', 'genres', 'tagline']
# Explicitly list columns used to generate the combined text for embeddings
COLUMNS_TO_EMBED = ['title', 'overview', 'genres', 'tagline']

# Ollama Config
OLLAMA_ENDPOINT = os.getenv("OLLAMA_ENDPOINT", "http://localhost:11434/api/embeddings")
OLLAMA_MODEL = os.getenv("OLLAMA_MODEL", "bge-m3") # Ensure you have pulled this model: ollama pull bge-m3
VECTOR_DIMENSION = 1024 # <--- IMPORTANT: Dimension of bge-m3 embeddings

# Azure AI Search Config
SEARCH_SERVICE_ENDPOINT = os.environ.get("AZURE_SEARCH_SERVICE_ENDPOINT")
SEARCH_API_KEY = os.environ.get("AZURE_SEARCH_API_KEY")
SEARCH_INDEX_NAME = os.environ.get("AZURE_SEARCH_INDEX_NAME", "movies-ollama-bge-m3-index") # Default index name

# Output/Processing Config
OUTPUT_FILE = f"movie_embeddings_{OLLAMA_MODEL}_{RECORDS_TO_PROCESS}records.jsonl" # For backup
UPLOAD_BATCH_SIZE = 100 # Upload documents in batches

# --- Ollama API Call Function ---
def get_ollama_embedding(text: str, model: str = OLLAMA_MODEL):
    """Calls the local Ollama API to get embeddings for the given text."""
    if pd.isna(text):
        text = "" # Treat NaN as empty string
    if not isinstance(text, str):
        text = str(text) # Attempt to convert non-strings

    text = text.strip()
    if not text:
        # print("Warning: Text is empty or whitespace. Skipping embedding.") # Less verbose
        return None

    # Optional: Add text length check/truncation if Ollama has limits
    # MAX_TEXT_LENGTH = 8000
    # if len(text) > MAX_TEXT_LENGTH:
    #     print(f"Warning: Truncating text longer than {MAX_TEXT_LENGTH} chars.")
    #     text = text[:MAX_TEXT_LENGTH]

    try:
        response = requests.post(
            OLLAMA_ENDPOINT,
            json={"model": model, "prompt": text},
            timeout=180 # Generous timeout for potentially long text or slow model
        )
        response.raise_for_status() # Raise HTTPError for bad responses (4xx or 5xx)
        response_json = response.json()

        if "embedding" in response_json:
            embedding = response_json["embedding"]
            if isinstance(embedding, list) and len(embedding) == VECTOR_DIMENSION:
                return embedding
            else:
                print(f"Error: Invalid embedding format/dimension (Expected: {VECTOR_DIMENSION}, Got: {len(embedding) if isinstance(embedding, list) else type(embedding)}). Text: '{text[:100]}...'")
                return None
        else:
            print(f"Error: 'embedding' key missing in response for text '{text[:100]}...'. Response: {response_json}")
            return None
    except requests.exceptions.Timeout:
        print(f"Error: Ollama API request timed out for text: '{text[:100]}...'")
    except requests.exceptions.ConnectionError:
        print(f"Error: Could not connect to Ollama API at {OLLAMA_ENDPOINT}. Is Ollama running?")
    except requests.exceptions.RequestException as e:
        print(f"Error calling Ollama API for text '{text[:100]}...': {e}")
    except json.JSONDecodeError:
        print(f"Error: Could not decode JSON response from Ollama API. Response Text: {response.text}")
    return None

# --- Azure Search: Create or Update Index Function ---
def create_or_update_index(endpoint: str, api_key: str, index_name: str, vector_dimension: int):
    """
    Creates a new Azure AI Search index or updates an existing one with the required schema.
    Returns True if successful, False otherwise.
    """
    print(f"Attempting to create or update search index '{index_name}'...")
    try:
        credential = AzureKeyCredential(api_key)
        index_client = SearchIndexClient(endpoint=endpoint, credential=credential)

        fields = [
            # Key field - must be string, unique, and filterable/sortable is good practice
            SimpleField(name="movie_id", type=SearchFieldDataType.String, key=True, sortable=True, filterable=True, facetable=False),
            # Searchable text fields
            SearchableField(name="title", type=SearchFieldDataType.String, sortable=True, filterable=True),
            SearchableField(name="overview", type=SearchFieldDataType.String),
            SearchableField(name="tagline", type=SearchFieldDataType.String),
            # Store genres as a single searchable/filterable/facetable string (e.g., "Action, Adventure, Science Fiction")
            SearchableField(name="genres", type=SearchFieldDataType.String, filterable=True, facetable=True),
            # Vector field for embeddings
            SearchField(
                name="embedding",
                type=SearchFieldDataType.Collection(SearchFieldDataType.Single),
                searchable=True, # Indicates it can be used in vector queries
                vector_search_dimensions=vector_dimension,
                vector_search_profile_name="my-hnsw-profile", # Links to the vector search profile
            ),
        ]

        # Vector Search Configuration
        vector_search = VectorSearch(
            profiles=[
                VectorSearchProfile(
                    name="my-hnsw-profile", # Must match profile name used in the 'embedding' field
                    algorithm_configuration_name="my-hnsw-config", # Links to the algorithm config
                )
            ],
            algorithms=[
                HnswAlgorithmConfiguration(
                    name="my-hnsw-config", # Must match algorithm name used in the profile
                    # Parameters like "metric" ("cosine", "euclidean", "dotProduct"), "m", "efConstruction", "efSearch" can be set here
                    # Default metric is "cosine", which is often suitable for text embeddings
                    parameters={"metric": "cosine"}
                )
            ],
        )

        # --- (Optional) Semantic Search Configuration ---
        # Requires Standard tier or higher Search Service and enabling Semantic Search on the service
        # Uncomment if needed:
        # semantic_search = SemanticSearch(
        #     configurations=[
        #         SemanticConfiguration(
        #             name="my-semantic-config", # Choose a name
        #             prioritized_fields=SemanticPrioritizedFields(
        #                 title_field=SemanticField(field_name="title"),
        #                 keywords_fields=[], # Optional keyword fields
        #                 content_fields=[
        #                     SemanticField(field_name="overview"),
        #                     SemanticField(field_name="tagline"),
        #                     SemanticField(field_name="genres"),
        #                 ]
        #             )
        #         )
        #     ]
        # )

        # --- Create the Index Object ---
        index = SearchIndex(
            name=index_name,
            fields=fields,
            vector_search=vector_search,
            # semantic_search=semantic_search # Uncomment if using semantic search
        )

        # --- Create or Update the Index in Azure ---
        # This command handles both creation and updates based on the index name
        result = index_client.create_or_update_index(index)
        print(f"Index '{result.name}' created or updated successfully.")
        return True

    except Exception as e:
        print(f"Error creating/updating index '{index_name}': {e}")
        # Consider more specific error handling if needed (e.g., authentication errors)
        return False


# --- Main Processing Logic ---
def process_movies_and_embed(dataframe_subset: pd.DataFrame):
    """
    Iterates through the provided DataFrame subset, combines text, generates embeddings,
    and returns documents formatted for Azure AI Search upload.
    """
    documents_for_upload = []
    processed_count = 0
    success_count = 0
    fail_count = 0

    if dataframe_subset.empty:
        print("Warning: Input DataFrame subset is empty. No records to process.")
        return documents_for_upload, success_count, fail_count

    # Verify required columns are present in the subset (should be guaranteed by read_csv if no errors)
    required_cols = ['id'] + COLUMNS_TO_EMBED
    if not all(col in dataframe_subset.columns for col in required_cols):
         print(f"Error: DataFrame subset is missing one or more required columns: {required_cols}")
         return [], 0, len(dataframe_subset) # Fail all

    print(f"\nStarting embedding generation and document preparation for {len(dataframe_subset)} movies...")
    print(f"Using combined text from columns: {', '.join(COLUMNS_TO_EMBED)}")

    for row in dataframe_subset.itertuples(index=False):
        processed_count += 1
        movie_id_raw = getattr(row, "id", None)
        movie_title = getattr(row, "title", "") # Default to empty string

        # --- Validate and Format ID (Critical for Azure Search Key) ---
        if pd.isna(movie_id_raw):
            print(f"  - Warning: Skipping record ~'{movie_title}' due to missing ID.")
            fail_count += 1
            continue
        # Ensure ID is a non-empty string
        movie_id = str(movie_id_raw).strip()
        if not movie_id:
            print(f"  - Warning: Skipping record ~'{movie_title}' due to empty ID after cleaning.")
            fail_count += 1
            continue

        # Ensure title is a string for consistent handling
        if pd.isna(movie_title): movie_title = ""
        if not isinstance(movie_title, str): movie_title = str(movie_title)
        movie_title = movie_title.strip()

        print(f"\nProcessing record {processed_count}: ID='{movie_id}', Title='{movie_title}'")

        # --- Combine Text from Specified Columns ---
        text_parts = []
        genre_names = [] # Store parsed genre names separately for the 'genres' field

        # Title
        if "title" in COLUMNS_TO_EMBED and movie_title:
            text_parts.append(movie_title)

        # Overview
        if "overview" in COLUMNS_TO_EMBED:
            overview = getattr(row, "overview", "")
            if pd.notna(overview) and isinstance(overview, str) and overview.strip():
                text_parts.append(overview.strip())

        # Tagline
        if "tagline" in COLUMNS_TO_EMBED:
            tagline = getattr(row, "tagline", "")
            if pd.notna(tagline) and isinstance(tagline, str) and tagline.strip():
                text_parts.append(tagline.strip())

        # Genres (Requires Parsing from string representation of list/dict)
        if "genres" in COLUMNS_TO_EMBED:
            genres_str = getattr(row, "genres", "[]") # Default to empty list string
            if pd.notna(genres_str) and isinstance(genres_str, str) and genres_str.strip() not in ('[]', '{}', ''):
                try:
                    # Safely evaluate the string: handles list of dicts like [{'id': 1, 'name': 'Action'}]
                    genres_list = ast.literal_eval(genres_str)
                    if isinstance(genres_list, list):
                        for genre_item in genres_list:
                            # Check if item is dict and has 'name' key with non-empty value
                            if isinstance(genre_item, dict) and 'name' in genre_item and genre_item['name']:
                                genre_name = str(genre_item['name']).strip()
                                if genre_name:
                                    genre_names.append(genre_name)
                except (SyntaxError, ValueError, TypeError) as e:
                    # Log parsing errors but continue processing the record
                    print(f"  - Warning: Could not parse genres for ID {movie_id}. Error: {e}. Genres string: '{genres_str[:100]}...'")

            if genre_names:
                 # Add the collected genre names as a single string part for embedding
                 text_parts.append(" ".join(genre_names)) # e.g., "Action Adventure Science Fiction"

        # --- Create the final combined text for embedding ---
        combined_text = ". ".join(filter(None, text_parts)) # Join non-empty parts with ". "

        if not combined_text.strip():
            print(f"  - Warning: Skipping ID '{movie_id}' ('{movie_title}') due to empty combined text after processing.")
            fail_count += 1
            continue

        # --- Generate the embedding ---
        print(f"  - Generating embedding for combined text (length: {len(combined_text)} chars).")
        embedding_vector = get_ollama_embedding(combined_text)

        # --- Prepare document for Azure Search ---
        if embedding_vector:
            print(f"  - Successfully generated embedding (dimension: {len(embedding_vector)}).")

            # --- Safely retrieve, convert, and clean text fields ---
            # Title is already cleaned earlier in the loop
            overview_raw = getattr(row, "overview", "")
            overview_cleaned = str(overview_raw).strip() # Convert to string THEN strip

            tagline_raw = getattr(row, "tagline", "")
            tagline_cleaned = str(tagline_raw).strip() # Convert to string THEN strip

            doc = {
                # Map DataFrame fields to Azure Search index fields
                "movie_id": movie_id, # Key field (string)
                "title": movie_title if movie_title else None, # Already cleaned
                "overview": overview_cleaned if overview_cleaned else None, # Assign None if empty after cleaning
                "tagline": tagline_cleaned if tagline_cleaned else None,   # Assign None if empty after cleaning
                "genres": ", ".join(genre_names) if genre_names else None, # Store as comma-separated string or None
                "embedding": embedding_vector, # The generated vector
                "@search.action": "mergeOrUpload" # Action for upload batch: updates if key exists, inserts if not
            }
            documents_for_upload.append(doc)
            success_count += 1
        else:
            print(f"  - Failed to generate embedding for ID '{movie_id}' ('{movie_title}'). Skipping document upload.")
            fail_count += 1 

    print(f"\nFinished processing {processed_count} records. Successful embeddings: {success_count}, Failed/Skipped: {fail_count}")
    return documents_for_upload, success_count, fail_count

# --- Function to save raw results to JSON Lines file (Backup) ---
def save_processed_docs_to_jsonl(documents: list, filename: str):
    """Saves the list of processed documents (formatted for upload) to a JSON Lines file."""
    if not documents:
        print("\nNo documents with successful embeddings to save to JSONL.")
        return
    print(f"\nAttempting to save {len(documents)} processed documents to {filename}...")
    saved_count = 0
    try:
        with open(filename, 'w', encoding='utf-8') as f:
            for record in documents:
                # Make a copy and remove the Azure Search action field before saving
                record_to_save = record.copy()
                record_to_save.pop("@search.action", None)

                # Optional: Add check for valid embedding before saving
                if not isinstance(record_to_save.get('embedding'), list):
                    print(f"Warning: Skipping record ID '{record_to_save.get('movie_id')}' in JSONL save due to invalid embedding.")
                    continue
                try:
                    json_string = json.dumps(record_to_save, ensure_ascii=False) # ensure_ascii=False for non-latin chars
                    f.write(json_string + '\n')
                    saved_count += 1
                except TypeError as e:
                    print(f"Error: Could not serialize record ID '{record_to_save.get('movie_id')}' to JSON. Error: {e}. Record: {record_to_save}")
        print(f"Successfully saved {saved_count} documents to {filename}")
    except IOError as e:
        print(f"Error: Could not write to file {filename}. Error: {e}")
    except Exception as e:
        print(f"An unexpected error occurred during file saving: {e}")

#--- Azure Search: Upload Documents Function ---
def upload_documents_to_index(endpoint: str, api_key: str, index_name: str, documents: list, batch_size: int = UPLOAD_BATCH_SIZE):
    """Uploads documents to the specified Azure AI Search index in batches."""
    if not documents:
        print("\nNo documents to upload.")
        return 0 # Return 0 uploaded

    print(f"\nUploading {len(documents)} documents to index '{index_name}' in batches of {batch_size}...")
    credential = AzureKeyCredential(api_key)
    search_client = SearchClient(endpoint=endpoint, index_name=index_name, credential=credential)

    num_batches = ceil(len(documents) / batch_size)
    total_uploaded_successfully = 0
    total_failed = 0

    for i in range(num_batches):
        start_idx = i * batch_size
        end_idx = start_idx + batch_size
        batch = documents[start_idx:end_idx]
        print(f"  Uploading batch {i+1}/{num_batches} ({len(batch)} documents)...")
        try:
            # upload_documents automatically handles batching internally, but we do it manually
            # for better progress reporting and potential error isolation per batch.
            # The `results` object details success/failure per document in the batch.
            results = search_client.upload_documents(documents=batch)

            batch_success_count = 0
            batch_fail_count = 0
            for result in results:
                if result.succeeded:
                    batch_success_count += 1
                else:
                    batch_fail_count += 1
                    # Log detailed error per document failure
                    print(f"    Failed to upload document ID '{result.key}': {result.error_message} (Status Code: {result.status_code})")

            total_uploaded_successfully += batch_success_count
            total_failed += batch_fail_count
            print(f"  Batch {i+1} result: {batch_success_count} succeeded, {batch_fail_count} failed.")

        except Exception as e:
            # Catch broader exceptions during the batch upload call itself
            print(f"  Error uploading batch {i+1}: {e}")
            # Assume all documents in this batch failed if the upload call itself threw an exception
            total_failed += len(batch)

    print(f"\nUpload finished. Total documents uploaded successfully: {total_uploaded_successfully}, Total failed: {total_failed}")
    return total_uploaded_successfully


# --- Main Execution Block ---
if __name__ == "__main__":
    print(f"Script started at {time.strftime('%Y-%m-%d %H:%M:%S')}")
    script_start_time = time.time()

    # --- Validate Azure Search Configuration ---
    if not SEARCH_SERVICE_ENDPOINT or "<" in SEARCH_SERVICE_ENDPOINT:
        print("Error: Azure Search Service Endpoint is not configured correctly. Set AZURE_SEARCH_SERVICE_ENDPOINT.")
        exit(1)
    if not SEARCH_API_KEY or "<" in SEARCH_API_KEY:
        print("Error: Azure Search Admin API Key is not configured correctly. Set AZURE_SEARCH_API_KEY.")
        exit(1)
    if not SEARCH_INDEX_NAME:
        print("Error: Search Index Name is not configured. Set SEARCH_INDEX_NAME.")
        exit(1)

    # --- 1. Create or Update Azure Search Index ---
    # This step ensures the index exists with the correct schema before processing data.
    # The Azure SDK handles the create/update logic.
    index_ready = create_or_update_index(
        endpoint=SEARCH_SERVICE_ENDPOINT,
        api_key=SEARCH_API_KEY,
        index_name=SEARCH_INDEX_NAME,
        vector_dimension=VECTOR_DIMENSION
    )

    if not index_ready:
        print("Exiting script because index creation/update failed.")
        exit(1) # Exit if index setup fails

    # --- 2. Read Data Subset ---
    df_processed = pd.DataFrame() # Initialize empty DataFrame
    try:
        print(f"\nReading columns {COLUMNS_TO_READ} for the first {RECORDS_TO_PROCESS} rows from '{FILE_PATH}'...")
        # Read only necessary columns and rows, crucial for large files.
        # Ensure 'id' is treated as a string, as it's the Azure Search key.
        df_processed = pd.read_csv(
            FILE_PATH,
            usecols=COLUMNS_TO_READ,
            nrows=RECORDS_TO_PROCESS,
            dtype={'id': str}, # Read 'id' column specifically as string
            low_memory=False # May help with mixed types, less critical with nrows/usecols
        )
        print(f"Successfully read {len(df_processed)} rows.")
        if len(df_processed) < RECORDS_TO_PROCESS:
             print(f"Info: Requested {RECORDS_TO_PROCESS} records, but the file (or section read) only contains {len(df_processed)}.")

    except FileNotFoundError:
        print(f"Error: File not found at '{FILE_PATH}'. Please check the path and filename.")
        exit(1)
    except ValueError as e:
        # Catch errors related to missing columns specified in 'usecols'
        print(f"Error reading CSV. Does the file '{FILE_PATH}' contain all required columns: {COLUMNS_TO_READ}? Error details: {e}")
        exit(1)
    except Exception as e:
        print(f"An unexpected error occurred reading the CSV file: {e}")
        exit(1)

    # --- 3. Process Movies and Generate Embeddings ---
    # Pass the already loaded subset DataFrame to the processing function
    documents_to_upload, successes, failures = process_movies_and_embed(df_processed)

    # --- 4. Save Processed Docs to JSONL (Backup) ---
    # Only save if there are documents that were successfully processed
    if documents_to_upload:
        save_processed_docs_to_jsonl(documents_to_upload, OUTPUT_FILE)
    else:
        print("\nNo documents with successful embeddings were generated, skipping JSONL backup.")

    # --- 5. Upload to Azure Search ---
    # Only upload if there are documents to upload
    if documents_to_upload:
        upload_documents_to_index(
            endpoint=SEARCH_SERVICE_ENDPOINT,
            api_key=SEARCH_API_KEY,
            index_name=SEARCH_INDEX_NAME,
            documents=documents_to_upload,
            batch_size=UPLOAD_BATCH_SIZE
        )
    else:
        print("\nSkipping upload to Azure Search as no documents were successfully processed.")

    # --- Finish ---
    script_end_time = time.time()
    print(f"\nScript finished at {time.strftime('%Y-%m-%d %H:%M:%S')}")
    print(f"Total execution time: {script_end_time - script_start_time:.2f} seconds")
# Out:
# Script started at 2025-04-09 20:13:06
# Attempting to create or update search index 'contosomoviesnomicembedtextidx'...
# Error creating/updating index 'contosomoviesnomicembedtextidx': (OperationNotAllowed) Existing field 'embedding' cannot be changed.
# Code: OperationNotAllowed
# Message: Existing field 'embedding' cannot be changed.
# Exception Details:	(CannotChangeExistingField) Existing field 'embedding' cannot be changed.
# 	Code: CannotChangeExistingField
# 	Message: Existing field 'embedding' cannot be changed.
# Exiting script because index creation/update failed.
#
# Reading columns ['id', 'title', 'overview', 'genres', 'tagline'] for the first None rows from '../data/raw/kaggle_movie_dataset/movies_metadata.csv'...
# Successfully read 45466 rows.
# An unexpected error occurred reading the CSV file: '<' not supported between instances of 'int' and 'NoneType'
#
# Starting embedding generation and document preparation for 45466 movies...
# Using combined text from columns: title, overview, genres, tagline
#
# Processing record 1: ID='862', Title='Toy Story'
#   - Generating embedding for combined text (length: 339 chars).
# Error: 'embedding' key missing in response for text 'Toy Story. Led by Woody, Andy's toys live happily in his room until Andy's birthday brings Buzz Ligh...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '862' ('Toy Story'). Skipping document upload.
#
# Processing record 2: ID='8844', Title='Jumanji'
#   - Generating embedding for combined text (length: 473 chars).
# Error: 'embedding' key missing in response for text 'Jumanji. When siblings Judy and Peter discover an enchanted board game that opens the door to a magi...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '8844' ('Jumanji'). Skipping document upload.
#
# Processing record 3: ID='15602', Title='Grumpier Old Men'
#   - Generating embedding for combined text (length: 415 chars).
# Error: 'embedding' key missing in response for text 'Grumpier Old Men. A family wedding reignites the ancient feud between next-door neighbors and fishin...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '15602' ('Grumpier Old Men'). Skipping document upload.
#
# Processing record 4: ID='31357', Title='Waiting to Exhale'
#   - Generating embedding for combined text (length: 391 chars).
# Error: 'embedding' key missing in response for text 'Waiting to Exhale. Cheated on, mistreated and stepped on, the women are holding their breath, waitin...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '31357' ('Waiting to Exhale'). Skipping document upload.
#
# Processing record 5: ID='11862', Title='Father of the Bride Part II'
#   - Generating embedding for combined text (length: 435 chars).
# Error: 'embedding' key missing in response for text 'Father of the Bride Part II. Just when George Banks has recovered from his daughter's wedding, he re...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '11862' ('Father of the Bride Part II'). Skipping document upload.
#
# Processing record 6: ID='949', Title='Heat'
#   - Generating embedding for combined text (length: 396 chars).
# Error: 'embedding' key missing in response for text 'Heat. Obsessive master thief, Neil McCauley leads a top-notch crew on various insane heists througho...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '949' ('Heat'). Skipping document upload.
#
# Processing record 7: ID='11860', Title='Sabrina'
#   - Generating embedding for combined text (length: 282 chars).
# Error: 'embedding' key missing in response for text 'Sabrina. An ugly duckling having undergone a remarkable change, still harbors feelings for her crush...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '11860' ('Sabrina'). Skipping document upload.
#
# Processing record 8: ID='45325', Title='Tom and Huck'
#   - Generating embedding for combined text (length: 421 chars).
# Error: 'embedding' key missing in response for text 'Tom and Huck. A mischievous young boy, Tom Sawyer, witnesses a murder by the deadly Injun Joe. Tom b...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '45325' ('Tom and Huck'). Skipping document upload.
#
# Processing record 9: ID='9091', Title='Sudden Death'
#   - Generating embedding for combined text (length: 517 chars).
# Error: 'embedding' key missing in response for text 'Sudden Death. International action superstar Jean Claude Van Damme teams with Powers Boothe in a Ten...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '9091' ('Sudden Death'). Skipping document upload.
#
# Processing record 10: ID='710', Title='GoldenEye'
#   - Generating embedding for combined text (length: 251 chars).
# Error: 'embedding' key missing in response for text 'GoldenEye. James Bond must unmask the mysterious head of the Janus Syndicate and prevent the leader ...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '710' ('GoldenEye'). Skipping document upload.
#
# Processing record 11: ID='9087', Title='The American President'
#   - Generating embedding for combined text (length: 395 chars).
# Error: 'embedding' key missing in response for text 'The American President. Widowed U.S. president Andrew Shepherd, one of the world's most powerful men...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '9087' ('The American President'). Skipping document upload.
#
# Processing record 12: ID='12110', Title='Dracula: Dead and Loving It'
#   - Generating embedding for combined text (length: 241 chars).
# Error: 'embedding' key missing in response for text 'Dracula: Dead and Loving It. When a lawyer shows up at the vampire's doorstep, he falls prey to his ...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '12110' ('Dracula: Dead and Loving It'). Skipping document upload.
#
# Processing record 13: ID='21032', Title='Balto'
#   - Generating embedding for combined text (length: 159 chars).
# Error: 'embedding' key missing in response for text 'Balto. An outcast half-wolf risks his life to prevent a deadly epidemic from ravaging Nome, Alaska.....'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '21032' ('Balto'). Skipping document upload.
#
# Processing record 14: ID='10858', Title='Nixon'
#   - Generating embedding for combined text (length: 398 chars).
# Error: 'embedding' key missing in response for text 'Nixon. An all-star cast powers this epic look at American President Richard M. Nixon, a man carrying...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '10858' ('Nixon'). Skipping document upload.
#
# Processing record 15: ID='1408', Title='Cutthroat Island'
#   - Generating embedding for combined text (length: 552 chars).
# Error: 'embedding' key missing in response for text 'Cutthroat Island. Morgan Adams and her slave, William Shaw, are on a quest to recover the three port...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '1408' ('Cutthroat Island'). Skipping document upload.
#
# Processing record 16: ID='524', Title='Casino'
#   - Generating embedding for combined text (length: 133 chars).
# Error: 'embedding' key missing in response for text 'Casino. The life of the gambling paradise – Las Vegas – and its dark mafia underbelly.. No one stays...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '524' ('Casino'). Skipping document upload.
#
# Processing record 17: ID='4584', Title='Sense and Sensibility'
#   - Generating embedding for combined text (length: 220 chars).
# Error: 'embedding' key missing in response for text 'Sense and Sensibility. Rich Mr. Dashwood dies, leaving his second wife and her daughters poor by the...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '4584' ('Sense and Sensibility'). Skipping document upload.
#
# Processing record 18: ID='5', Title='Four Rooms'
#   - Generating embedding for combined text (length: 420 chars).
# Error: 'embedding' key missing in response for text 'Four Rooms. It's Ted the Bellhop's first night on the job...and the hotel's very unusual guests are ...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '5' ('Four Rooms'). Skipping document upload.
#
# Processing record 19: ID='9273', Title='Ace Ventura: When Nature Calls'
#   - Generating embedding for combined text (length: 436 chars).
# Error: 'embedding' key missing in response for text 'Ace Ventura: When Nature Calls. Summoned from an ashram in Tibet, Ace finds himself on a perilous jo...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '9273' ('Ace Ventura: When Nature Calls'). Skipping document upload.
#
# Processing record 20: ID='11517', Title='Money Train'
#   - Generating embedding for combined text (length: 196 chars).
# Error: 'embedding' key missing in response for text 'Money Train. A vengeful New York transit cop decides to steal a trainload of subway fares; his foste...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '11517' ('Money Train'). Skipping document upload.
#
# Processing record 21: ID='8012', Title='Get Shorty'
#   - Generating embedding for combined text (length: 497 chars).
# Error: 'embedding' key missing in response for text 'Get Shorty. Chili Palmer is a Miami mobster who gets sent by his boss, the psychopathic "Bones" Barb...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '8012' ('Get Shorty'). Skipping document upload.
#
# Processing record 22: ID='1710', Title='Copycat'
#   - Generating embedding for combined text (length: 308 chars).
# Error: 'embedding' key missing in response for text 'Copycat. An agoraphobic psychologist and a female detective must work together to take down a serial...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '1710' ('Copycat'). Skipping document upload.
#
# Processing record 23: ID='9691', Title='Assassins'
#   - Generating embedding for combined text (length: 551 chars).
# Error: 'embedding' key missing in response for text 'Assassins. Assassin Robert Rath arrives at a funeral to kill a prominent mobster, only to witness a ...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '9691' ('Assassins'). Skipping document upload.
#
# Processing record 24: ID='12665', Title='Powder'
#   - Generating embedding for combined text (length: 426 chars).
# Error: 'embedding' key missing in response for text 'Powder. Harassed by classmates who won't accept his shocking appearance, a shy young man known as "P...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '12665' ('Powder'). Skipping document upload.
#
# Processing record 25: ID='451', Title='Leaving Las Vegas'
#   - Generating embedding for combined text (length: 304 chars).
# Error: 'embedding' key missing in response for text 'Leaving Las Vegas. Ben Sanderson, an alcoholic Hollywood screenwriter who lost everything because of...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '451' ('Leaving Las Vegas'). Skipping document upload.
#
# Processing record 26: ID='16420', Title='Othello'
#   - Generating embedding for combined text (length: 192 chars).
# Error: 'embedding' key missing in response for text 'Othello. The evil Iago pretends to be friend of Othello in order to manipulate him to serve his own ...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '16420' ('Othello'). Skipping document upload.
#
# Processing record 27: ID='9263', Title='Now and Then'
#   - Generating embedding for combined text (length: 399 chars).
# Error: 'embedding' key missing in response for text 'Now and Then. Waxing nostalgic about the bittersweet passage from childhood to puberty in this tende...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '9263' ('Now and Then'). Skipping document upload.
#
# Processing record 28: ID='17015', Title='Persuasion'
#   - Generating embedding for combined text (length: 475 chars).
# Error: 'embedding' key missing in response for text 'Persuasion. This film adaptation of Jane Austen's last novel follows Anne Elliot, the daughter of a ...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '17015' ('Persuasion'). Skipping document upload.
#
# Processing record 29: ID='902', Title='The City of Lost Children'
#   - Generating embedding for combined text (length: 221 chars).
# Error: 'embedding' key missing in response for text 'The City of Lost Children. A scientist in a surrealist society kidnaps children to steal their dream...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '902' ('The City of Lost Children'). Skipping document upload.
#
# Processing record 30: ID='37557', Title='Shanghai Triad'
#   - Generating embedding for combined text (length: 259 chars).
# Error: 'embedding' key missing in response for text 'Shanghai Triad. A provincial boy related to a Shanghai crime family is recruited by his uncle into c...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '37557' ('Shanghai Triad'). Skipping document upload.
#
# Processing record 31: ID='9909', Title='Dangerous Minds'
#   - Generating embedding for combined text (length: 518 chars).
# Error: 'embedding' key missing in response for text 'Dangerous Minds. Former Marine Louanne Johnson lands a gig teaching in a pilot program for bright bu...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '9909' ('Dangerous Minds'). Skipping document upload.
#
# Processing record 32: ID='63', Title='Twelve Monkeys'
#   - Generating embedding for combined text (length: 664 chars).
# Error: 'embedding' key missing in response for text 'Twelve Monkeys. In the year 2035, convict James Cole reluctantly volunteers to be sent back in time ...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '63' ('Twelve Monkeys'). Skipping document upload.
#
# Processing record 33: ID='78802', Title='Wings of Courage'
#   - Generating embedding for combined text (length: 35 chars).
# Error: 'embedding' key missing in response for text 'Wings of Courage. Romance Adventure...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '78802' ('Wings of Courage'). Skipping document upload.
#
# Processing record 34: ID='9598', Title='Babe'
#   - Generating embedding for combined text (length: 447 chars).
# Error: 'embedding' key missing in response for text 'Babe. Babe is a little pig who doesn't quite know his place in the world. With a bunch of odd friend...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '9598' ('Babe'). Skipping document upload.
#
# Processing record 35: ID='47018', Title='Carrington'
#   - Generating embedding for combined text (length: 623 chars).
# Error: 'embedding' key missing in response for text 'Carrington. The story of the relationship between painter Dora Carrington and author Lytton Strachey...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '47018' ('Carrington'). Skipping document upload.
#
# Processing record 36: ID='687', Title='Dead Man Walking'
#   - Generating embedding for combined text (length: 349 chars).
# Error: 'embedding' key missing in response for text 'Dead Man Walking. A justice drama based on a true story about a man on death row who in his last day...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '687' ('Dead Man Walking'). Skipping document upload.
#
# Processing record 37: ID='139405', Title='Across the Sea of Time'
#   - Generating embedding for combined text (length: 700 chars).
# Error: 'embedding' key missing in response for text 'Across the Sea of Time. A young Russian boy, Thomas Minton, travels to New York as a passenger on a ...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '139405' ('Across the Sea of Time'). Skipping document upload.
#
# Processing record 38: ID='33689', Title='It Takes Two'
#   - Generating embedding for combined text (length: 342 chars).
# Error: 'embedding' key missing in response for text 'It Takes Two. Identical 9-year-olds from very different backgrounds: orphaned Amanda and wealthy Aly...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '33689' ('It Takes Two'). Skipping document upload.
#
# Processing record 39: ID='9603', Title='Clueless'
#   - Generating embedding for combined text (length: 524 chars).
# Error: 'embedding' key missing in response for text 'Clueless. Shallow, rich and socially successful Cher is at the top of her Beverly Hills high school'...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '9603' ('Clueless'). Skipping document upload.
#
# Processing record 40: ID='34615', Title='Cry, the Beloved Country'
#   - Generating embedding for combined text (length: 135 chars).
# Error: 'embedding' key missing in response for text 'Cry, the Beloved Country. A South-African preacher goes to search for his wayward son who has commit...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '34615' ('Cry, the Beloved Country'). Skipping document upload.
#
# Processing record 41: ID='31174', Title='Richard III'
#   - Generating embedding for combined text (length: 116 chars).
# Error: 'embedding' key missing in response for text 'Richard III. Shakespeare's Play transplanted into a 1930s setting.. I can smile, and murder while I ...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '31174' ('Richard III'). Skipping document upload.
#
# Processing record 42: ID='11443', Title='Dead Presidents'
#   - Generating embedding for combined text (length: 445 chars).
# Error: 'embedding' key missing in response for text 'Dead Presidents. Depicts a heist of old bills, retired from circulation and destined by the governme...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '11443' ('Dead Presidents'). Skipping document upload.
#
# Processing record 43: ID='35196', Title='Restoration'
#   - Generating embedding for combined text (length: 775 chars).
# Error: 'embedding' key missing in response for text 'Restoration. An aspiring young physician, Robert Merivel found himself in the service of King Charle...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '35196' ('Restoration'). Skipping document upload.
#
# Processing record 44: ID='9312', Title='Mortal Kombat'
#   - Generating embedding for combined text (length: 502 chars).
# Error: 'embedding' key missing in response for text 'Mortal Kombat. For nine generations an evil sorcerer has been victorious in hand-to-hand battle agai...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '9312' ('Mortal Kombat'). Skipping document upload.
#
# Processing record 45: ID='577', Title='To Die For'
#   - Generating embedding for combined text (length: 305 chars).
# Error: 'embedding' key missing in response for text 'To Die For. Susan wants to work in television and will therefore do anything it takes, even if it me...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '577' ('To Die For'). Skipping document upload.
#
# Processing record 46: ID='11861', Title='How To Make An American Quilt'
#   - Generating embedding for combined text (length: 535 chars).
# Error: 'embedding' key missing in response for text 'How To Make An American Quilt. Soon-to-be-wed graduate student Finn Dodd develops cold feet when she...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '11861' ('How To Make An American Quilt'). Skipping document upload.
#
# Processing record 47: ID='807', Title='Se7en'
#   - Generating embedding for combined text (length: 460 chars).
# Error: 'embedding' key missing in response for text 'Se7en. Two homicide detectives are on a desperate hunt for a serial killer whose crimes are based on...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '807' ('Se7en'). Skipping document upload.
#
# Processing record 48: ID='10530', Title='Pocahontas'
#   - Generating embedding for combined text (length: 410 chars).
# Error: 'embedding' key missing in response for text 'Pocahontas. History comes gloriously to life in Disney's epic animated tale about love and adventure...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '10530' ('Pocahontas'). Skipping document upload.
#
# Processing record 49: ID='8391', Title='When Night Is Falling'
#   - Generating embedding for combined text (length: 245 chars).
# Error: 'embedding' key missing in response for text 'When Night Is Falling. A prudish woman, working on tenure as a literacy professor at a large urban u...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '8391' ('When Night Is Falling'). Skipping document upload.
#
# Processing record 50: ID='629', Title='The Usual Suspects'
#   - Generating embedding for combined text (length: 497 chars).
# Error: 'embedding' key missing in response for text 'The Usual Suspects. Held in an L.A. interrogation room, Verbal Kint attempts to convince the feds th...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '629' ('The Usual Suspects'). Skipping document upload.
#
# Processing record 51: ID='117164', Title='Guardian Angel'
#   - Generating embedding for combined text (length: 547 chars).
# Error: 'embedding' key missing in response for text 'Guardian Angel. Detective - turned - bodyguard Cynthia McKay (Cynthia Rothrock) is hired by a psycho...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '117164' ('Guardian Angel'). Skipping document upload.
#
# Processing record 52: ID='11448', Title='Mighty Aphrodite'
#   - Generating embedding for combined text (length: 453 chars).
# Error: 'embedding' key missing in response for text 'Mighty Aphrodite. When Lenny and his wife, Amanda, adopt a baby, Lenny realizes that his son is a ge...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '11448' ('Mighty Aphrodite'). Skipping document upload.
#
# Processing record 53: ID='49133', Title='Lamerica'
#   - Generating embedding for combined text (length: 554 chars).
# Error: 'embedding' key missing in response for text 'Lamerica. Fiore, an Italian conman, arrives in post Communist Albania with Gino, his young apprentic...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '49133' ('Lamerica'). Skipping document upload.
#
# Processing record 54: ID='26441', Title='The Big Green'
#   - Generating embedding for combined text (length: 432 chars).
# Error: 'embedding' key missing in response for text 'The Big Green. In a depressed Texas town, British foreign exchange teacher Anna attempts to inject s...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '26441' ('The Big Green'). Skipping document upload.
#
# Processing record 55: ID='97406', Title='Georgia'
#   - Generating embedding for combined text (length: 476 chars).
# Error: 'embedding' key missing in response for text 'Georgia. Sadie looks up to her older sister Georgia, a successful folk singer who's happily married ...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '97406' ('Georgia'). Skipping document upload.
#
# Processing record 56: ID='124057', Title='Kids of the Round Table'
#   - Generating embedding for combined text (length: 123 chars).
# Error: 'embedding' key missing in response for text 'Kids of the Round Table. Set in modern times, Alex finds King Arthur's sword Excalibur and must prov...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '124057' ('Kids of the Round Table'). Skipping document upload.
#
# Processing record 57: ID='9089', Title='Home for the Holidays'
#   - Generating embedding for combined text (length: 351 chars).
# Error: 'embedding' key missing in response for text 'Home for the Holidays. After losing her job, making out with her soon to be ex-boss, and finding out...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '9089' ('Home for the Holidays'). Skipping document upload.
#
# Processing record 58: ID='11010', Title='The Postman'
#   - Generating embedding for combined text (length: 162 chars).
# Error: 'embedding' key missing in response for text 'The Postman. Simple Italian postman learns to love poetry while delivering mail to a famous poet; he...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '11010' ('The Postman'). Skipping document upload.
#
# Processing record 59: ID='99040', Title='The Confessional'
#   - Generating embedding for combined text (length: 611 chars).
# Error: 'embedding' key missing in response for text 'The Confessional. The year is 1952, in Quebec City. Rachel (16), unmarried and pregnant, works in th...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '99040' ('The Confessional'). Skipping document upload.
#
# Processing record 60: ID='11359', Title='The Indian in the Cupboard'
#   - Generating embedding for combined text (length: 216 chars).
# Error: 'embedding' key missing in response for text 'The Indian in the Cupboard. A nine-year-old boy gets a plastic Indian and a cupboard for his birthda...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '11359' ('The Indian in the Cupboard'). Skipping document upload.
#
# Processing record 61: ID='17182', Title='Eye for an Eye'
#   - Generating embedding for combined text (length: 289 chars).
# Error: 'embedding' key missing in response for text 'Eye for an Eye. It's fire and brimstone time as grieving mother Karen McCann takes justice into her ...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '17182' ('Eye for an Eye'). Skipping document upload.
#
# Processing record 62: ID='2054', Title='Mr. Holland's Opus'
#   - Generating embedding for combined text (length: 453 chars).
# Error: 'embedding' key missing in response for text 'Mr. Holland's Opus. In 1965, passionate musician Glenn Holland takes a day job as a high school musi...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '2054' ('Mr. Holland's Opus'). Skipping document upload.
#
# Processing record 63: ID='10607', Title='Don't Be a Menace to South Central While Drinking Your Juice in the Hood'
#   - Generating embedding for combined text (length: 621 chars).
# Error: 'embedding' key missing in response for text 'Don't Be a Menace to South Central While Drinking Your Juice in the Hood. When Ashtray (Shawn Wayans...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '10607' ('Don't Be a Menace to South Central While Drinking Your Juice in the Hood'). Skipping document upload.
#
# Processing record 64: ID='19760', Title='Two If by Sea'
#   - Generating embedding for combined text (length: 469 chars).
# Error: 'embedding' key missing in response for text 'Two If by Sea. Frank O'Brien, a petty thief, and his 7-year-long girlfriend Roz want to put an end t...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '19760' ('Two If by Sea'). Skipping document upload.
#
# Processing record 65: ID='9536', Title='Bio-Dome'
#   - Generating embedding for combined text (length: 498 chars).
# Error: 'embedding' key missing in response for text 'Bio-Dome. Bud and Doyle are two losers who are doing nothing with their lives. Both of their girlfri...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '9536' ('Bio-Dome'). Skipping document upload.
#
# Processing record 66: ID='11525', Title='Lawnmower Man 2: Beyond Cyberspace'
#   - Generating embedding for combined text (length: 423 chars).
# Error: 'embedding' key missing in response for text 'Lawnmower Man 2: Beyond Cyberspace. Jobe is resuscitated by Jonathan Walker. He wants Jobe to create...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '11525' ('Lawnmower Man 2: Beyond Cyberspace'). Skipping document upload.
#
# Processing record 67: ID='40628', Title='Two Bits'
#   - Generating embedding for combined text (length: 582 chars).
# Error: 'embedding' key missing in response for text 'Two Bits. It's a hot summer day in 1933 in South Philly, where 12-year old Gennaro lives with his wi...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '40628' ('Two Bits'). Skipping document upload.
#
# Processing record 68: ID='4482', Title='French Twist'
#   - Generating embedding for combined text (length: 187 chars).
# Error: 'embedding' key missing in response for text 'French Twist. After learning of her husband's infidelities, a housewife invites an itinerant lesbian...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '4482' ('French Twist'). Skipping document upload.
#
# Processing record 69: ID='10634', Title='Friday'
#   - Generating embedding for combined text (length: 213 chars).
# Error: 'embedding' key missing in response for text 'Friday. Craig and Smokey are two guys in Los Angeles hanging out on their porch on a Friday afternoo...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '10634' ('Friday'). Skipping document upload.
#
# Processing record 70: ID='755', Title='From Dusk Till Dawn'
#   - Generating embedding for combined text (length: 481 chars).
# Error: 'embedding' key missing in response for text 'From Dusk Till Dawn. Seth Gecko and his younger brother Richard are on the run after a bloody bank r...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '755' ('From Dusk Till Dawn'). Skipping document upload.
#
# Processing record 71: ID='11859', Title='Fair Game'
#   - Generating embedding for combined text (length: 243 chars).
# Error: 'embedding' key missing in response for text 'Fair Game. Max Kirkpatrick is a cop who protects Kate McQuean, a civil law attorney, from a renegade...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '11859' ('Fair Game'). Skipping document upload.
#
# Processing record 72: ID='28387', Title='Kicking and Screaming'
#   - Generating embedding for combined text (length: 540 chars).
# Error: 'embedding' key missing in response for text 'Kicking and Screaming. After college graduation, Grover's girlfriend Jane tells him she's moving to ...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '28387' ('Kicking and Screaming'). Skipping document upload.
#
# Processing record 73: ID='48750', Title='Les Miserables'
#   - Generating embedding for combined text (length: 366 chars).
# Error: 'embedding' key missing in response for text 'Les Miserables. In France during World War II, a poor and illiterate man, Henri Fortin (Jean-Paul Be...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '48750' ('Les Miserables'). Skipping document upload.
#
# Processing record 74: ID='20927', Title='Bed of Roses'
#   - Generating embedding for combined text (length: 340 chars).
# Error: 'embedding' key missing in response for text 'Bed of Roses. The seeds of love are planted when Lisa, a high-powered investment banker, receives fl...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '20927' ('Bed of Roses'). Skipping document upload.
#
# Processing record 75: ID='36929', Title='Big Bully'
#   - Generating embedding for combined text (length: 243 chars).
# Error: 'embedding' key missing in response for text 'Big Bully. A writer returns to his hometown where he faces the childhood nemesis whose life he ultim...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '36929' ('Big Bully'). Skipping document upload.
#
# Processing record 76: ID='9102', Title='Screamers'
#   - Generating embedding for combined text (length: 358 chars).
# Error: 'embedding' key missing in response for text 'Screamers. (SIRIUS 6B, Year 2078) On a distant mining planet ravaged by a decade of war, scientists ...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '9102' ('Screamers'). Skipping document upload.
#
# Processing record 77: ID='124626', Title='Nico Icon'
#   - Generating embedding for combined text (length: 331 chars).
# Error: 'embedding' key missing in response for text 'Nico Icon. A look into the many lives of Christa Päffgen, otherwise known as Nico; from cutie German...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '124626' ('Nico Icon'). Skipping document upload.
#
# Processing record 78: ID='27526', Title='The Crossing Guard'
#   - Generating embedding for combined text (length: 615 chars).
# Error: 'embedding' key missing in response for text 'The Crossing Guard. After his daughter died in a hit and run, Freddy Gale has waited six years for J...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '27526' ('The Crossing Guard'). Skipping document upload.
#
# Processing record 79: ID='9623', Title='The Juror'
#   - Generating embedding for combined text (length: 469 chars).
# Error: 'embedding' key missing in response for text 'The Juror. With his gangster boss on trial for murder, a mob thug known as "the Teacher" tells Annie...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '9623' ('The Juror'). Skipping document upload.
#
# Processing record 80: ID='46785', Title='The White Balloon'
#   - Generating embedding for combined text (length: 158 chars).
# Error: 'embedding' key missing in response for text 'The White Balloon. Several people try to take advantage of a little girl's innocence to hustle money...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '46785' ('The White Balloon'). Skipping document upload.
#
# Processing record 81: ID='400', Title='Things to Do in Denver When You're Dead'
#   - Generating embedding for combined text (length: 291 chars).
# Error: 'embedding' key missing in response for text 'Things to Do in Denver When You're Dead. A mafia film in Tarantino style with a star-studded cast. J...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '400' ('Things to Do in Denver When You're Dead'). Skipping document upload.
#
# Processing record 82: ID='880', Title='Antonia's Line'
#   - Generating embedding for combined text (length: 520 chars).
# Error: 'embedding' key missing in response for text 'Antonia's Line. After World War II, Antonia and her daughter, Danielle, go back to their Dutch homet...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '880' ('Antonia's Line'). Skipping document upload.
#
# Processing record 83: ID='146599', Title='Once Upon a Time... When We Were Colored'
#   - Generating embedding for combined text (length: 773 chars).
# Error: 'embedding' key missing in response for text 'Once Upon a Time... When We Were Colored. This film relates the story of a tightly connected Afro-Am...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '146599' ('Once Upon a Time... When We Were Colored'). Skipping document upload.
#
# Processing record 84: ID='188588', Title='Last Summer in the Hamptons'
#   - Generating embedding for combined text (length: 702 chars).
# Error: 'embedding' key missing in response for text 'Last Summer in the Hamptons. Filmed entirely on location in East Hampton, Long Island, "Last Summer ...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '188588' ('Last Summer in the Hamptons'). Skipping document upload.
#
# Processing record 85: ID='8447', Title='Angels and Insects'
#   - Generating embedding for combined text (length: 540 chars).
# Error: 'embedding' key missing in response for text 'Angels and Insects. In Victorian England, wealthy patriarch Sir Harald Alabaster invites an impoveri...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '8447' ('Angels and Insects'). Skipping document upload.
#
# Processing record 86: ID='10534', Title='White Squall'
#   - Generating embedding for combined text (length: 108 chars).
# Error: 'embedding' key missing in response for text 'White Squall. Teenage boys discover discipline and camaraderie on an ill-fated sailing voyage.. Acti...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '10534' ('White Squall'). Skipping document upload.
#
# Processing record 87: ID='17414', Title='Dunston Checks In'
#   - Generating embedding for combined text (length: 451 chars).
# Error: 'embedding' key missing in response for text 'Dunston Checks In. Hotel manager Robert Grant is forced by his boss to postpone his family vacation ...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '17414' ('Dunston Checks In'). Skipping document upload.
#
# Processing record 88: ID='13997', Title='Black Sheep'
#   - Generating embedding for combined text (length: 356 chars).
# Error: 'embedding' key missing in response for text 'Black Sheep. When dignified Albert Donnelly runs for Governor, his team moves to keep his slow-witte...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '13997' ('Black Sheep'). Skipping document upload.
#
# Processing record 89: ID='2086', Title='Nick of Time'
#   - Generating embedding for combined text (length: 271 chars).
# Error: 'embedding' key missing in response for text 'Nick of Time. Gene Watson is a public accountant who arrives on a train at Union Station in Los Ange...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '2086' ('Nick of Time'). Skipping document upload.
#
# Processing record 90: ID='61548', Title='The Journey of August King'
#   - Generating embedding for combined text (length: 522 chars).
# Error: 'embedding' key missing in response for text 'The Journey of August King. The Journey of August King is a multi-dimensional drama about a North Ca...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '61548' ('The Journey of August King'). Skipping document upload.
#
# Processing record 91: ID='9095', Title='Mary Reilly'
#   - Generating embedding for combined text (length: 171 chars).
# Error: 'embedding' key missing in response for text 'Mary Reilly. A housemaid falls in love with Dr. Jekyll and his darkly mysterious counterpart, Mr. Hy...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '9095' ('Mary Reilly'). Skipping document upload.
#
# Processing record 92: ID='12158', Title='Vampire in Brooklyn'
#   - Generating embedding for combined text (length: 367 chars).
# Error: 'embedding' key missing in response for text 'Vampire in Brooklyn. Maximillian, the lone survivor of a race of vampires, comes to Brooklyn in sear...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '12158' ('Vampire in Brooklyn'). Skipping document upload.
#
# Processing record 93: ID='9283', Title='Beautiful Girls'
#   - Generating embedding for combined text (length: 287 chars).
# Error: 'embedding' key missing in response for text 'Beautiful Girls. During a snowy winter in the small fictional town of Knight"s Ridge, Massachusetts,...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '9283' ('Beautiful Girls'). Skipping document upload.
#
# Processing record 94: ID='9208', Title='Broken Arrow'
#   - Generating embedding for combined text (length: 433 chars).
# Error: 'embedding' key missing in response for text 'Broken Arrow. When rogue stealth-fighter pilot Vic Deakins deliberately drops off the radar while on...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '9208' ('Broken Arrow'). Skipping document upload.
#
# Processing record 95: ID='40154', Title='A Midwinter's Tale'
#   - Generating embedding for combined text (length: 673 chars).
# Error: 'embedding' key missing in response for text 'A Midwinter's Tale. Out of work actor Joe volunteers to help try and save his sister's local church ...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '40154' ('A Midwinter's Tale'). Skipping document upload.
#
# Processing record 96: ID='406', Title='La Haine'
#   - Generating embedding for combined text (length: 394 chars).
# Error: 'embedding' key missing in response for text 'La Haine. Aimlessly whiling away their days in the concrete environs of their dead-end suburbia, Vin...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '406' ('La Haine'). Skipping document upload.
#
# Processing record 97: ID='45549', Title='Shopping'
#   - Generating embedding for combined text (length: 529 chars).
# Error: 'embedding' key missing in response for text 'Shopping. A dark, hip, urban story of a barren and anonymous city where the underclass' sport of cho...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '45549' ('Shopping'). Skipping document upload.
#
# Processing record 98: ID='63076', Title='Heidi Fleiss: Hollywood Madam'
#   - Generating embedding for combined text (length: 707 chars).
# Error: 'embedding' key missing in response for text 'Heidi Fleiss: Hollywood Madam. A documentary crew from the BBC arrives in L.A. intent on interviewin...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '63076' ('Heidi Fleiss: Hollywood Madam'). Skipping document upload.
#
# Processing record 99: ID='11062', Title='City Hall'
#   - Generating embedding for combined text (length: 260 chars).
# Error: 'embedding' key missing in response for text 'City Hall. The accidental shooting of a boy in New York leads to an investigation by the Deputy Mayo...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '11062' ('City Hall'). Skipping document upload.
#
# Processing record 100: ID='13685', Title='Bottle Rocket'
#   - Generating embedding for combined text (length: 420 chars).
# Error: 'embedding' key missing in response for text 'Bottle Rocket. Upon his release from a mental hospital following a nervous breakdown, the directionl...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '13685' ('Bottle Rocket'). Skipping document upload.
#
# Processing record 101: ID='47475', Title='Mr. Wrong'
#   - Generating embedding for combined text (length: 253 chars).
# Error: 'embedding' key missing in response for text 'Mr. Wrong. A single and lonely woman finds the seemingly perfect man to date, but soon regrets it wh...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '47475' ('Mr. Wrong'). Skipping document upload.
#
# Processing record 102: ID='2045', Title='Unforgettable'
#   - Generating embedding for combined text (length: 669 chars).
# Error: 'embedding' key missing in response for text 'Unforgettable. Ray Liotta stars as a medical examiner who has been acquitted for his wife's murder b...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '2045' ('Unforgettable'). Skipping document upload.
#
# Processing record 103: ID='9614', Title='Happy Gilmore'
#   - Generating embedding for combined text (length: 380 chars).
# Error: 'embedding' key missing in response for text 'Happy Gilmore. Failed hockey player-turned-golf whiz Happy Gilmore -- whose unconventional approach ...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '9614' ('Happy Gilmore'). Skipping document upload.
#
# Processing record 104: ID='688', Title='The Bridges of Madison County'
#   - Generating embedding for combined text (length: 250 chars).
# Error: 'embedding' key missing in response for text 'The Bridges of Madison County. Photographer Robert Kincaid wanders into the life of housewife France...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '688' ('The Bridges of Madison County'). Skipping document upload.
#
# Processing record 105: ID='11907', Title='Nobody Loves Me'
#   - Generating embedding for combined text (length: 56 chars).
# Error: 'embedding' key missing in response for text 'Nobody Loves Me. No overview found.. Drama Comedy Family...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '11907' ('Nobody Loves Me'). Skipping document upload.
#
# Processing record 106: ID='10874', Title='Muppet Treasure Island'
#   - Generating embedding for combined text (length: 488 chars).
# Error: 'embedding' key missing in response for text 'Muppet Treasure Island. After telling the story of Flint's last journey to young Jim Hawkins, Billy ...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '10874' ('Muppet Treasure Island'). Skipping document upload.
#
# Processing record 107: ID='89333', Title='Catwalk'
#   - Generating embedding for combined text (length: 232 chars).
# Error: 'embedding' key missing in response for text 'Catwalk. A documentary following Christy Turlington and other models during spring fashion week in M...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '89333' ('Catwalk'). Skipping document upload.
#
# Processing record 108: ID='96357', Title='Headless Body in Topless Bar'
#   - Generating embedding for combined text (length: 96 chars).
# Error: 'embedding' key missing in response for text 'Headless Body in Topless Bar. An ex-con holds a group of people hostage in a topless bar.. Crime...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '96357' ('Headless Body in Topless Bar'). Skipping document upload.
#
# Processing record 109: ID='197', Title='Braveheart'
#   - Generating embedding for combined text (length: 340 chars).
# ...
#   - Failed to generate embedding for ID '31640' ('Blood and Wine'). Skipping document upload.
#
# Processing record 1305: ID='8744', Title='Albino Alligator'
#   - Generating embedding for combined text (length: 390 chars).
# Error: 'embedding' key missing in response for text 'Albino Alligator. Three petty thieves who the police believe to be major criminals are chased into a...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '8744' ('Albino Alligator'). Skipping document upload.
#
# Processing record 1306: ID='25189', Title='The Mirror Has Two Faces'
#   - Generating embedding for combined text (length: 451 chars).
# Error: 'embedding' key missing in response for text 'The Mirror Has Two Faces. Rose Morgan (Barbara Streisand), who still lives with her mother (Lauren B...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '25189' ('The Mirror Has Two Faces'). Skipping document upload.
#
# Processing record 1307: ID='145', Title='Breaking the Waves'
#   - Generating embedding for combined text (length: 243 chars).
# Error: 'embedding' key missing in response for text 'Breaking the Waves. In a small and conservative Scottish village, a woman's paralytic husband convin...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '145' ('Breaking the Waves'). Skipping document upload.
#
# Processing record 1308: ID='2212', Title='Nightwatch'
#   - Generating embedding for combined text (length: 196 chars).
# Error: 'embedding' key missing in response for text 'Nightwatch. A law student, who takes a job as a night watchman at a morgue, begins to discover clues...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '2212' ('Nightwatch'). Skipping document upload.
#
# Processing record 1309: ID='199', Title='Star Trek: First Contact'
#   - Generating embedding for combined text (length: 398 chars).
# Error: 'embedding' key missing in response for text 'Star Trek: First Contact. The Borg, a relentless race of cyborgs, are on a direct course for Earth. ...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '199' ('Star Trek: First Contact'). Skipping document upload.
#
# Processing record 1310: ID='7863', Title='Shine'
#   - Generating embedding for combined text (length: 224 chars).
# Error: 'embedding' key missing in response for text 'Shine. Pianist David Helfgott, driven by his father and teachers, has a breakdown. Years later he re...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '7863' ('Shine'). Skipping document upload.
#
# Processing record 1311: ID='12498', Title='Sling Blade'
#   - Generating embedding for combined text (length: 307 chars).
# Error: 'embedding' key missing in response for text 'Sling Blade. Karl Childers is a mentally disabled man who has been in the custody of the state menta...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '12498' ('Sling Blade'). Skipping document upload.
#
# Processing record 1312: ID='9279', Title='Jingle All the Way'
#   - Generating embedding for combined text (length: 575 chars).
# Error: 'embedding' key missing in response for text 'Jingle All the Way. Meet Howard Langston, a salesman for a mattress company is constantly busy at hi...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '9279' ('Jingle All the Way'). Skipping document upload.
#
# Processing record 1313: ID='53234', Title='Identification of a Woman'
#   - Generating embedding for combined text (length: 457 chars).
# Error: 'embedding' key missing in response for text 'Identification of a Woman. The movie director Niccolò has just been left by his wife. Subsequently h...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '53234' ('Identification of a Woman'). Skipping document upload.
#
# Processing record 1314: ID='17204', Title='Paradise Lost: The Child Murders at Robin Hood Hills'
#   - Generating embedding for combined text (length: 223 chars).
# Error: 'embedding' key missing in response for text 'Paradise Lost: The Child Murders at Robin Hood Hills. A horrific triple child murder leads to an ind...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '17204' ('Paradise Lost: The Child Murders at Robin Hood Hills'). Skipping document upload.
#
# Processing record 1315: ID='21539', Title='The Preacher's Wife'
#   - Generating embedding for combined text (length: 493 chars).
# Error: 'embedding' key missing in response for text 'The Preacher's Wife. Good natured Reverend Henry Biggs finds that his marriage to choir mistress Jul...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '21539' ('The Preacher's Wife'). Skipping document upload.
#
# Processing record 1316: ID='85589', Title='Zero Kelvin'
#   - Generating embedding for combined text (length: 517 chars).
# Error: 'embedding' key missing in response for text 'Zero Kelvin. Larsen, an aspiring poet in '20s Oslo, leaves his girlfriend to spend a year as a trapp...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '85589' ('Zero Kelvin'). Skipping document upload.
#
# Processing record 1317: ID='12709', Title='Ridicule'
#   - Generating embedding for combined text (length: 170 chars).
# Error: 'embedding' key missing in response for text 'Ridicule. To get royal backing on a needed drainage project, a poor French lord must learn to play t...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '12709' ('Ridicule'). Skipping document upload.
#
# Processing record 1318: ID='20539', Title='The Crucible'
#   - Generating embedding for combined text (length: 259 chars).
# Error: 'embedding' key missing in response for text 'The Crucible. The movie is centered around the Salem Massachusetts witch trials of 1692. The movie i...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '20539' ('The Crucible'). Skipping document upload.
#
# Processing record 1319: ID='11674', Title='101 Dalmatians'
#   - Generating embedding for combined text (length: 275 chars).
# Error: 'embedding' key missing in response for text '101 Dalmatians. The Live action adaptation of a Disney Classic. When a litter of dalmatian puppies a...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '11674' ('101 Dalmatians'). Skipping document upload.
#
# Processing record 1320: ID='199512', Title='The Forbidden Christ'
#   - Generating embedding for combined text (length: 814 chars).
# Error: 'embedding' key missing in response for text 'The Forbidden Christ. Strange Deception combines a standard revenge tale with a postwar reenactment ...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '199512' ('The Forbidden Christ'). Skipping document upload.
#
# Processing record 1321: ID='64900', Title='I Can't Sleep'
#   - Generating embedding for combined text (length: 728 chars).
# Error: 'embedding' key missing in response for text 'I Can't Sleep. Ninon is a spirited hotel-manager who teaches self-defense classes to her terrified e...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '64900' ('I Can't Sleep'). Skipping document upload.
#
# Processing record 1322: ID='1573', Title='Die Hard 2'
#   - Generating embedding for combined text (length: 442 chars).
# Error: 'embedding' key missing in response for text 'Die Hard 2. John McClane is an off-duty cop gripped with a feeling of déjà vu when on a snowy Christ...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '1573' ('Die Hard 2'). Skipping document upload.
#
# Processing record 1323: ID='152', Title='Star Trek: The Motion Picture'
#   - Generating embedding for combined text (length: 278 chars).
# Error: 'embedding' key missing in response for text 'Star Trek: The Motion Picture. When a destructive space entity is spotted approaching Earth, Admiral...'. Response: {'model': 'nomic-embed-text', 'embeddings': []}
#   - Failed to generate embedding for ID '152' ('Star Trek: The Motion Picture'). Skipping document upload.
#
# Processing record 1324: ID='174', Title='Star Trek VI: The Undiscovered Country'
#   - Generating embedding for combined text (length: 346 chars).
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 472
#     468     exit(1)
#     470 # --- 3. Process Movies and Generate Embeddings ---
#     471 # Pass the already loaded subset DataFrame to the processing function
# --> 472 documents_to_upload, successes, failures = process_movies_and_embed(df_processed)
#     474 # --- 4. Save Processed Docs to JSONL (Backup) ---
#     475 # Only save if there are documents that were successfully processed
#     476 if documents_to_upload:
#
# Cell In[2], line 298, in process_movies_and_embed(dataframe_subset)
#     296 # --- Generate the embedding ---
#     297 print(f"  - Generating embedding for combined text (length: {len(combined_text)} chars).")
# --> 298 embedding_vector = get_ollama_embedding(combined_text)
#     300 # --- Prepare document for Azure Search ---
#     301 if embedding_vector:
#
# Cell In[2], line 82, in get_ollama_embedding(text, model)
#      75 # Optional: Add text length check/truncation if Ollama has limits
#      76 # MAX_TEXT_LENGTH = 8000
#      77 # if len(text) > MAX_TEXT_LENGTH:
#      78 #     print(f"Warning: Truncating text longer than {MAX_TEXT_LENGTH} chars.")
#      79 #     text = text[:MAX_TEXT_LENGTH]
#      81 try:
# ---> 82     response = requests.post(
#      83         OLLAMA_ENDPOINT,
#      84         json={"model": model, "prompt": text},
#      85         timeout=180 # Generous timeout for potentially long text or slow model
#      86     )
#      87     response.raise_for_status() # Raise HTTPError for bad responses (4xx or 5xx)
#      88     response_json = response.json()
#
# File ~/Projects/Contoso/Embedding/venv/lib/python3.13/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)    112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~/Projects/Contoso/Embedding/venv/lib/python3.13/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Projects/Contoso/Embedding/venv/lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Projects/Contoso/Embedding/venv/lib/python3.13/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Projects/Contoso/Embedding/venv/lib/python3.13/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/Projects/Contoso/Embedding/venv/lib/python3.13/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/Projects/Contoso/Embedding/venv/lib/python3.13/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/Projects/Contoso/Embedding/venv/lib/python3.13/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File /usr/local/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File /usr/local/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File /usr/local/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File /usr/local/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/lib/python3.13/socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
import requests
import json
import pandas as pd
import time
import os
import ast # Needed for safely evaluating string representations of lists/dicts
# Removed ThreadPoolExecutor imports as we'll use request batching
from azure.core.credentials import AzureKeyCredential
from azure.search.documents import SearchClient
from azure.search.documents.indexes import SearchIndexClient
from azure.search.documents.indexes.models import (
    SearchIndex,
    SearchField,
    SearchFieldDataType,
    SimpleField,
    SearchableField,
    VectorSearch,
    VectorSearchProfile,
    HnswAlgorithmConfiguration,
)
from math import ceil
from dotenv import load_dotenv

# --- Load Environment Variables ---
# Assuming .env is in the parent directory
dotenv_path = "../.env"
if os.path.exists(dotenv_path):
    load_dotenv(dotenv_path)
else:
    print("Warning: .env file not found in parent directory.")
    # Attempt loading from current directory if needed
    load_dotenv()


# --- Configuration ---

# Data Source Config
FILE_PATH = os.getenv("SOURCE_FILE_PATH", "movies_metadata.csv")
if not FILE_PATH:
    print("Error: SOURCE_FILE_PATH environment variable not set.")
    exit(1)
# For 45k rows, let's set this appropriately or remove the limit if you want all
RECORDS_TO_PROCESS = 46000 # Adjust as needed, or remove 'nrows' in pd.read_csv to process all
COLUMNS_TO_READ = ['id', 'title', 'overview', 'genres', 'tagline']
COLUMNS_TO_EMBED = ['title', 'overview', 'genres', 'tagline']

# Ollama Config
OLLAMA_ENDPOINT = os.getenv("OLLAMA_ENDPOINT", "http://localhost:11434/api/embed")
OLLAMA_MODEL = os.getenv("OLLAMA_MODEL", "nomic-embed-text") # Ensure pulled: ollama pull nomic-embed-text
VECTOR_DIMENSION = 768 # Correct for nomic-embed-text
OLLAMA_BATCH_SIZE = int(os.getenv("OLLAMA_BATCH_SIZE", 32))

# Azure AI Search Config
SEARCH_SERVICE_ENDPOINT = os.environ.get("AZURE_SEARCH_SERVICE_ENDPOINT")
SEARCH_API_KEY = os.environ.get("AZURE_SEARCH_API_KEY")
SEARCH_INDEX_NAME = os.environ.get("AZURE_SEARCH_INDEX_NAME", f"movies-ollama-{OLLAMA_MODEL.replace('/','-')}-index")

# Processing & Output Config
# Ensure OUTPUT_PATH exists or handle its creation
output_dir = os.getenv("OUTPUT_PATH", ".") # Default to current directory if not set
os.makedirs(output_dir, exist_ok=True) # Create output directory if it doesn't exist
# Construct full output file path
OUTPUT_FILE = os.path.join(output_dir, f"movie_embeddings_{OLLAMA_MODEL.replace('/','-')}_{RECORDS_TO_PROCESS}records.jsonl")
UPLOAD_BATCH_SIZE = 100 # Batch size for uploading docs TO AZURE SEARCH

# --- Ollama API Call Function for Batch Embeddings ---
# (Keep the function as it is in your original code)
def get_ollama_embeddings_batch(texts: list[str], model: str):
    """Calls the local Ollama API (/api/embed) to get embeddings for a batch of texts."""
    global VECTOR_DIMENSION # Access global dimension for validation

    if not texts: # Handle empty input list
        return []

    try:
        # Adjust endpoint if needed based on your Ollama setup
        response = requests.post(
            OLLAMA_ENDPOINT,
            json={"model": model, "prompt": "", "input": texts}, # Key is "input" for batch
            timeout=300 # Increased timeout
        )
        response.raise_for_status()
        response_json = response.json()

        # Validate response structure from /api/embed
        if "embeddings" in response_json and isinstance(response_json["embeddings"], list):
            embeddings_list = response_json["embeddings"]
            if len(embeddings_list) == len(texts):
                 # Minimal validation for speed - check first embedding's dimension if needed
                 # if embeddings_list and (not isinstance(embeddings_list[0], list) or len(embeddings_list[0]) != VECTOR_DIMENSION):
                 #      print(f"Error: Unexpected vector dimension. Expected {VECTOR_DIMENSION}, Got: {len(embeddings_list[0])}")
                 #      return None
                 return embeddings_list
            else:
                print(f"Error: Mismatch between input texts ({len(texts)}) and returned embeddings ({len(embeddings_list)}) from model '{model}'.")
                return None
        else:
             print(f"Error: 'embeddings' key missing or invalid in batch response for model '{model}'. Response: {response_json}")
             return None

    except requests.exceptions.Timeout:
        print(f"Error: Ollama API request timed out for batch request. Model: '{model}', Batch Size: {len(texts)}")
    except requests.exceptions.ConnectionError:
        print(f"Error: Could not connect to Ollama API at {OLLAMA_ENDPOINT}. Is Ollama running?")
    except requests.exceptions.RequestException as e:
        print(f"Error calling Ollama API for batch request. Model: '{model}', Batch Size: {len(texts)}: {e}")
    except json.JSONDecodeError:
        print(f"Error: Could not decode JSON response from Ollama API. Response Text: {response.text}")
    return None


# --- Azure Search: Create or Update Index Function ---
# (Keep the function as it is in your original code)
def create_or_update_index(endpoint: str, api_key: str, index_name: str, vector_dimension: int):
    """Creates/updates Azure AI Search index. Returns True if successful."""
    print(f"Attempting to create or update search index '{index_name}' with vector dimension {vector_dimension}...")
    try:
        credential = AzureKeyCredential(api_key)
        index_client = SearchIndexClient(endpoint=endpoint, credential=credential)
        fields = [
            SimpleField(name="movie_id", type=SearchFieldDataType.String, key=True, sortable=True, filterable=True, facetable=False),
            SearchableField(name="title", type=SearchFieldDataType.String, sortable=True, filterable=True),
            SearchableField(name="overview", type=SearchFieldDataType.String),
            SearchableField(name="tagline", type=SearchFieldDataType.String),
            SearchableField(name="genres", type=SearchFieldDataType.String, filterable=True, facetable=True),
            SearchField(
                name="embedding",
                type=SearchFieldDataType.Collection(SearchFieldDataType.Single),
                searchable=True,
                vector_search_dimensions=vector_dimension,
                vector_search_profile_name="my-hnsw-profile",
            ),
        ]
        vector_search = VectorSearch(
            profiles=[VectorSearchProfile(name="my-hnsw-profile", algorithm_configuration_name="my-hnsw-config")],
            algorithms=[HnswAlgorithmConfiguration(name="my-hnsw-config", parameters={"metric": "cosine"})],
        )
        index = SearchIndex(name=index_name, fields=fields, vector_search=vector_search)
        result = index_client.create_or_update_index(index)
        print(f"Index '{result.name}' created or updated successfully.")
        return True
    except Exception as e:
        print(f"Error creating/updating index '{index_name}': {e}")
        return False


# --- Text Preparation Helper ---
# (Keep the function as it is in your original code)
def prepare_text_and_metadata(row_tuple):
    """Prepares combined text and metadata from a row tuple."""
    global COLUMNS_TO_EMBED
    movie_id = None
    try:
        movie_id_raw = getattr(row_tuple, "id", None)
        movie_title = getattr(row_tuple, "title", "")

        # Added stricter ID check
        if pd.isna(movie_id_raw) or str(movie_id_raw).strip() == '': return None, None
        movie_id = str(movie_id_raw).strip()

        # Handle potential NaN/missing titles robustly
        if pd.isna(movie_title): movie_title = ""
        if not isinstance(movie_title, str): movie_title = str(movie_title)
        movie_title = movie_title.strip()

        text_parts = []
        genre_names = []

        if "title" in COLUMNS_TO_EMBED and movie_title:
            text_parts.append(f"Title: {movie_title}") # Adding labels might help

        overview_raw = getattr(row_tuple, "overview", "")
        overview_cleaned = ""
        if pd.notna(overview_raw) and str(overview_raw).strip():
             overview_cleaned = str(overview_raw).strip()
             if "overview" in COLUMNS_TO_EMBED:
                text_parts.append(f"Overview: {overview_cleaned}")

        tagline_raw = getattr(row_tuple, "tagline", "")
        tagline_cleaned = ""
        if pd.notna(tagline_raw) and str(tagline_raw).strip():
             tagline_cleaned = str(tagline_raw).strip()
             if "tagline" in COLUMNS_TO_EMBED:
                 text_parts.append(f"Tagline: {tagline_cleaned}")

        genres_cleaned_str = None
        if "genres" in COLUMNS_TO_EMBED:
            genres_str = getattr(row_tuple, "genres", "[]")
            if pd.notna(genres_str) and isinstance(genres_str, str) and genres_str.strip() not in ('[]', '{}', ''):
                try:
                    # Robust parsing for various possible string formats
                    potential_list = ast.literal_eval(genres_str)
                    if isinstance(potential_list, list):
                        for item in potential_list:
                            if isinstance(item, dict) and 'name' in item and item['name'] and str(item['name']).strip():
                                genre_names.append(str(item['name']).strip())
                            elif isinstance(item, str) and item.strip(): # Handle case where it's just a list of strings
                                genre_names.append(item.strip())
                except (ValueError, SyntaxError, TypeError):
                     # Fallback: Treat as simple comma-separated string if literal_eval fails
                     if ',' in genres_str:
                         genre_names.extend([g.strip() for g in genres_str.split(',') if g.strip()])
                     elif genres_str.strip(): # Treat as a single genre if no commas
                         genre_names.append(genres_str.strip())
            if genre_names:
                text_parts.append(f"Genres: {', '.join(genre_names)}")
                genres_cleaned_str = ", ".join(genre_names) # For metadata field

        combined_text = " ".join(filter(None, text_parts)).strip()
        # Ensure we have at least an ID and some text to proceed
        if not combined_text: return None, None

        metadata = {
            "movie_id": movie_id,
            # Use cleaned versions or None if empty/NaN originally
            "title": movie_title if movie_title else None,
            "overview": overview_cleaned if overview_cleaned else None,
            "tagline": tagline_cleaned if tagline_cleaned else None,
            "genres": genres_cleaned_str, # Already joined string or None
        }
        return combined_text, metadata

    except Exception as e:
        print(f"Error preparing text/metadata for potential ID '{getattr(row_tuple, 'id', 'UNKNOWN')}': {e}")
        return None, None


# --- Function to save raw results to JSON Lines file (Backup) ---
# (Keep the function as it is - it will be called at the end with all *successfully* processed docs)
def save_processed_docs_to_jsonl(documents: list, filename: str):
    """Saves the final list of successfully processed documents (with embeddings) to a JSON Lines file."""
    if not documents:
        print("\nNo documents with successful embeddings to save to JSONL.")
        return
    # Filter out documents that might be missing embeddings before saving
    docs_to_save = [doc for doc in documents if isinstance(doc.get('embedding'), list)]
    if not docs_to_save:
        print("\nNo documents with valid embeddings found to save to JSONL.")
        return

    print(f"\nAttempting to save {len(docs_to_save)} processed documents to {filename}...")
    saved_count = 0
    try:
        # Use 'w' mode to overwrite any previous incomplete file from prior runs
        with open(filename, 'w', encoding='utf-8') as f:
            for record in docs_to_save:
                record_to_save = record.copy()
                # Remove the search action field before saving, if present
                record_to_save.pop("@search.action", None)
                try:
                    json_string = json.dumps(record_to_save, ensure_ascii=False)
                    f.write(json_string + '\n')
                    saved_count += 1
                except TypeError as e:
                    print(f"Error: Could not serialize record ID '{record_to_save.get('movie_id')}' to JSON. Error: {e}. Record: {record_to_save}")
        print(f"Successfully saved {saved_count} documents to {filename}")
    except IOError as e:
        print(f"Error: Could not write to file {filename}. Error: {e}")
    except Exception as e:
        print(f"An unexpected error occurred during file saving: {e}")


#--- Azure Search: Upload Documents Function ---
# (Keep the function as it is in your original code - it handles batching internally)
def upload_documents_to_index(endpoint: str, api_key: str, index_name: str, documents: list, batch_size: int = UPLOAD_BATCH_SIZE):
    """Uploads a list of documents to the specified Azure Search index."""
    if not documents:
        print("\n(upload_documents_to_index) No documents provided for upload.")
        return 0
    # Ensure documents have the @search.action field
    for doc in documents:
        if "@search.action" not in doc:
            doc["@search.action"] = "mergeOrUpload" # Default action

    print(f"\nUploading {len(documents)} documents to index '{index_name}' (Azure client handles internal batching)...")
    credential = AzureKeyCredential(api_key)
    search_client = SearchClient(endpoint=endpoint, index_name=index_name, credential=credential)
    try:
        results = search_client.upload_documents(documents=documents)
        # Check results
        success_count = sum(1 for result in results if result.succeeded)
        fail_count = len(documents) - success_count
        total_uploaded_successfully = success_count

        print(f"  Upload attempt finished. Succeeded: {success_count}, Failed: {fail_count}")
        if fail_count > 0:
             for result in results:
                 if not result.succeeded:
                      # Limit error message length if it's very long
                      error_message = str(result.error_message)
                      if len(error_message) > 500:
                          error_message = error_message[:500] + "... (truncated)"
                      print(f"    Failed doc ID '{result.key}': {error_message}")
        return total_uploaded_successfully
    except Exception as e:
        print(f"  Error during bulk upload: {e}")
        # You might want more sophisticated error handling here,
        # like attempting smaller batches or individual uploads on failure.
        return 0


# --- Main Execution Block ---
if __name__ == "__main__":
    print(f"Script started at {time.strftime('%Y-%m-%d %H:%M:%S')}")
    print(f"Using Ollama model: {OLLAMA_MODEL} (Vector Dim: {VECTOR_DIMENSION}) at {OLLAMA_ENDPOINT}")
    print(f"Processing up to {RECORDS_TO_PROCESS} records.")
    print(f"Ollama embedding batch size: {OLLAMA_BATCH_SIZE}")
    print(f"Azure Search upload batch size: {UPLOAD_BATCH_SIZE}")
    script_start_time = time.time()

    # --- Validate Config ---
    if not SEARCH_SERVICE_ENDPOINT or "<" in SEARCH_SERVICE_ENDPOINT or not SEARCH_SERVICE_ENDPOINT.startswith("https"):
        print("Error: Azure Search Service Endpoint not configured correctly (should start with https://)."); exit(1)
    if not SEARCH_API_KEY or "<" in SEARCH_API_KEY:
        print("Error: Azure Search Admin API Key not configured."); exit(1)
    if not SEARCH_INDEX_NAME:
        print("Error: Search Index Name not configured."); exit(1)
    if not os.path.exists(FILE_PATH):
        print(f"Error: Source file not found at '{FILE_PATH}'."); exit(1)

    # --- 1. Create or Update Azure Search Index ---
    index_ready = create_or_update_index(
        endpoint=SEARCH_SERVICE_ENDPOINT,
        api_key=SEARCH_API_KEY,
        index_name=SEARCH_INDEX_NAME,
        vector_dimension=VECTOR_DIMENSION
    )
    if not index_ready: print("Exiting script because index creation/update failed."); exit(1)

    # --- 2. Read Data Subset ---
    df_processed = pd.DataFrame()
    actual_records_read = 0
    try:
        print(f"\nReading columns {COLUMNS_TO_READ} for first {RECORDS_TO_PROCESS} rows from '{FILE_PATH}'...")
        # Consider using chunking for very large files if memory is an issue
        df_processed = pd.read_csv(
            FILE_PATH,
            usecols=COLUMNS_TO_READ,
            nrows=RECORDS_TO_PROCESS,
            dtype={'id': str}, # Keep ID as string
            low_memory=False,
            on_bad_lines='warn' # or 'skip' if you prefer
        )
        # Drop rows where essential columns for embedding are missing entirely AFTER reading
        df_processed.dropna(subset=['id', 'title', 'overview'], how='any', inplace=True)
        # Reset index after dropping rows if needed, though itertuples handles it
        df_processed.reset_index(drop=True, inplace=True)

        actual_records_read = len(df_processed)
        print(f"Successfully read and initially filtered {actual_records_read} rows.")
        if actual_records_read < RECORDS_TO_PROCESS:
             print(f"Info: Requested {RECORDS_TO_PROCESS}, file/section contains {actual_records_read} after initial read/filtering.")
    except FileNotFoundError: print(f"Error: File not found at '{FILE_PATH}'."); exit(1)
    except ValueError as e: print(f"Error reading CSV. Check columns {COLUMNS_TO_READ} are present in '{FILE_PATH}'. Details: {e}"); exit(1)
    except Exception as e: print(f"An unexpected error occurred reading CSV: {e}"); exit(1)


    # --- 3. Process Movies, Generate Embeddings, and Upload Incrementally ---
    # Use one list to accumulate docs for Azure upload batching
    documents_for_azure_batch = []
    # Use a separate list to keep track of ALL successfully processed docs for final JSONL backup
    all_successful_documents_for_backup = []
    total_processed_count = 0
    success_embedding_count = 0
    fail_count = 0
    total_uploaded_count = 0 # Track total docs successfully sent to Azure

    if df_processed.empty:
        print("DataFrame is empty after initial filtering, skipping embedding generation.")
    else:
        num_ollama_batches = ceil(actual_records_read / OLLAMA_BATCH_SIZE)
        print(f"\nStarting batch embedding generation for {actual_records_read} movies in {num_ollama_batches} Ollama batches...")
        processing_start_time = time.time()

        for i in range(num_ollama_batches):
            batch_start_time = time.time()
            start_idx = i * OLLAMA_BATCH_SIZE
            end_idx = min(start_idx + OLLAMA_BATCH_SIZE, actual_records_read) # Ensure end_idx doesn't exceed actual rows
            df_batch = df_processed.iloc[start_idx:end_idx] # Use iloc for positional slicing

            print(f"\nProcessing Ollama Batch {i+1}/{num_ollama_batches} (Rows {start_idx+1}-{end_idx})...")

            texts_to_embed = []
            batch_metadata = [] # Store corresponding metadata for successful text preps
            batch_prep_fail_count = 0 # Count failures within this batch's prep stage

            # Prepare texts and metadata for the current Ollama batch
            for row_tuple in df_batch.itertuples(index=False, name='MovieRow'): # Use iloc, so index=False is safe
                total_processed_count += 1
                combined_text, metadata = prepare_text_and_metadata(row_tuple)
                if combined_text and metadata and metadata.get("movie_id"): # Ensure ID is valid
                    texts_to_embed.append(combined_text)
                    batch_metadata.append(metadata)
                else:
                    batch_prep_fail_count += 1 # Count prep failures (missing ID, no text, etc.)

            fail_count += batch_prep_fail_count # Add prep failures to total fail count

            if not texts_to_embed:
                print(f"  Ollama Batch {i+1}: No valid text generated from rows. Skipping API call.")
                continue # Skip to next Ollama batch if no texts were prepared

            # Call Ollama API for the batch of prepared texts
            print(f"  Ollama Batch {i+1}: Sending {len(texts_to_embed)} texts to Ollama...")
            embeddings_batch = get_ollama_embeddings_batch(texts_to_embed, OLLAMA_MODEL)

            # Process the batch response
            if embeddings_batch and len(embeddings_batch) == len(batch_metadata):
                print(f"  Ollama Batch {i+1}: Received {len(embeddings_batch)} embeddings successfully.")
                # Combine embeddings with metadata and add to the upload queue
                batch_docs_processed_count = 0
                for embedding, meta in zip(embeddings_batch, batch_metadata):
                     # Basic check on received embedding before adding
                     if isinstance(embedding, list) and len(embedding) == VECTOR_DIMENSION:
                         doc = meta.copy() # Start with prepared metadata
                         doc["embedding"] = embedding
                         # doc["@search.action"] = "mergeOrUpload" # Action added in upload func if needed
                         documents_for_azure_batch.append(doc)
                         all_successful_documents_for_backup.append(doc) # Also add to backup list
                         success_embedding_count += 1
                         batch_docs_processed_count += 1
                     else:
                         print(f"  Warning: Skipping record ID '{meta.get('movie_id')}' due to invalid embedding vector received in batch.")
                         fail_count += 1

                print(f"  Ollama Batch {i+1}: Added {batch_docs_processed_count} docs to upload queue (Current queue size: {len(documents_for_azure_batch)}).")

                # --- >>> MODIFICATION: Trigger Azure upload if batch size reached <<< ---
                if len(documents_for_azure_batch) >= UPLOAD_BATCH_SIZE:
                    print(f"\n--- Triggering intermediate Azure upload: Queue size ({len(documents_for_azure_batch)}) >= Upload batch size ({UPLOAD_BATCH_SIZE}) ---")
                    uploaded_in_batch = upload_documents_to_index(
                        endpoint=SEARCH_SERVICE_ENDPOINT,
                        api_key=SEARCH_API_KEY,
                        index_name=SEARCH_INDEX_NAME,
                        documents=documents_for_azure_batch, # Upload the accumulated batch
                        batch_size=UPLOAD_BATCH_SIZE # Pass Azure batch size for info (client handles actual batching)
                    )
                    if uploaded_in_batch > 0:
                        total_uploaded_count += uploaded_in_batch
                        documents_for_azure_batch = [] # IMPORTANT: Clear the list after successful upload attempt
                        print(f"--- Intermediate upload finished. Cleared queue. Total uploaded so far: {total_uploaded_count} ---")
                    else:
                        print(f"--- WARNING: Intermediate upload attempt failed for {len(documents_for_azure_batch)} documents. They remain in the queue. ---")
                        # Decide on error handling: stop? retry later? skip these docs?
                        # For now, they stay in the queue and will be retried with the next batch trigger or final upload.

            else:
                # API call failed or returned incorrect number of embeddings for the batch
                print(f"  Ollama Batch {i+1}: Failed to get embeddings for {len(batch_metadata)} items.")
                fail_count += len(batch_metadata) # Mark all items in this API call as failed

            batch_duration = time.time() - batch_start_time
            print(f"  Ollama Batch {i+1} processing time: {batch_duration:.2f} seconds")
            # Estimate remaining time
            if success_embedding_count > 0:
                elapsed_time = time.time() - processing_start_time
                avg_time_per_doc = elapsed_time / success_embedding_count
                remaining_docs = actual_records_read - total_processed_count
                estimated_remaining_time = remaining_docs * avg_time_per_doc
                print(f"  Estimated time remaining: {estimated_remaining_time / 60:.1f} minutes")


        total_processing_duration = time.time() - processing_start_time
        print(f"\nFinished embedding generation loop.")
        print(f"Total items processed (read rows attempted): {total_processed_count}")
        print(f"Successful embeddings generated: {success_embedding_count}, Failed/Skipped: {fail_count}")
        if success_embedding_count > 0:
             print(f"Average time per successful embedding (processing phase): {total_processing_duration / success_embedding_count:.3f} seconds")


    # --- 4. Upload any remaining documents ---
    if documents_for_azure_batch:
        print(f"\n--- Triggering final upload for remaining {len(documents_for_azure_batch)} documents ---")
        uploaded_in_final_batch = upload_documents_to_index(
            endpoint=SEARCH_SERVICE_ENDPOINT,
            api_key=SEARCH_API_KEY,
            index_name=SEARCH_INDEX_NAME,
            documents=documents_for_azure_batch,
            batch_size=UPLOAD_BATCH_SIZE
        )
        if uploaded_in_final_batch > 0:
            total_uploaded_count += uploaded_in_final_batch
            print(f"--- Final upload finished. Total documents uploaded overall: {total_uploaded_count} ---")
        else:
             print(f"--- WARNING: Final upload attempt failed for {len(documents_for_azure_batch)} documents. ---")
        documents_for_azure_batch = [] # Clear list
    else:
        print("\nNo remaining documents needed final upload.")


    # --- 5. Save ALL Processed Docs (with embeddings) to JSONL (Backup) ---
    # This now saves everything that was successfully embedded, regardless of when it was uploaded
    if all_successful_documents_for_backup:
        save_processed_docs_to_jsonl(all_successful_documents_for_backup, OUTPUT_FILE)
    else:
        print("\nNo documents successfully embedded, skipping JSONL backup.")


    # --- Finish ---
    script_end_time = time.time()
    print(f"\nScript finished at {time.strftime('%Y-%m-%d %H:%M:%S')}")
    print(f"Total execution time: {(script_end_time - script_start_time):.2f} seconds")
    print(f"Total documents successfully uploaded to Azure Search: {total_uploaded_count}")
    print(f"Total documents successfully embedded (and saved to backup): {success_embedding_count}")
    print(f"Total documents failed or skipped during processing: {fail_count}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 26
#      22 from dotenv import load_dotenv
#      24 # --- Load Environment Variables ---
#      25 # Assuming .env is in the parent directory
# ---> 26 dotenv_path = os.path.join(os.path.dirname(__file__), '..', '.env')
#      27 if os.path.exists(dotenv_path):
#      28     load_dotenv(dotenv_path)
#
# NameError: name '__file__' is not defined
